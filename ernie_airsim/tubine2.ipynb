# %%
import ernie_airsim
ernie_airsim = ernie_airsim.ErnieAirSim()

# %%
command = ""
python_code = ernie_airsim.process(command)
print("python_code:", python_code)

# %%
command = "wind turbine1,X and wind turbine3distance toward wind turbine"
python_code = ernie_airsim.process(command)
print("python_code:", python_code)

# %%
command = " use 2wind turbine. X and wind turbine212distance toward turbine, 50 altitude position. "
python_code = ernie_airsim.process(command)
print("python_code:", python_code)

# %%
command = "note, Z is toward is toward, toward toward, for reply with "
python_code = ernie_airsim.process(command)
print("python_code:", python_code)

# %%
command = " in let begincheckwind turbine. # toward above, before position above 30, after times toward below. "
python_code = ernie_airsim.process(command)
print("python_code:", python_code)

# %%
command = " check #, need to with and -30 below toward. should in YZ above 30 distance, after return before position. "
python_code = ernie_airsim.process(command)
print("python_code:", python_code)

# %%
command = " has small, toward below, Zshould is, or above, -30 sinvalue is "
python_code = ernie_airsim.process(command)
print("python_code:", python_code)

# %%
command = " in need tocheck. need to, but after below, no return"
python_code = ernie_airsim.process(command)
print("python_code:", python_code)

# %%
command =" in toward before, wind turbine after. in X above 20, above between, after drone 180. can use set_yaw() functiondrone. "
python_code = ernie_airsim.process(command)
print("python_code:", python_code)

# %%
command = " good! in need check. this and before all, also is, above toward. "
python_code = ernie_airsim.process(command)
print("python_code:", python_code)

# %%
command = " is has small, in is, and 180, with, is and before and before after. toward above, Yshould is. altitude is, Zshould is "
python_code = ernie_airsim.process(command)
print("python_code:", python_code)
