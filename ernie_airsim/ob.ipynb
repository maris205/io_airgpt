# %%
import ernie_airsim
ernie_airsim = ernie_airsim.ErnieAirSim()

# %%
command = """
false to XYZ target. controldrone, let target, before. drone not toward target, small before, in each new evaluation. 

drone distancesensor, return and drone before distance. canthroughcall aw.get_distance(). 

has in drone before distance few 10 below can. if has, drone, before few has 10 between, ddrone after, drone before toward toward small distance. distance after, not need times for target.? 

"""
python_code = ernie_airsim.process(command)
print("python_code:", python_code)

# %%
command = """
not, has with below small: 
1 drone angle, i.e., not need to toward. 
2 no before position and targetposition not need tocomplete, need distance small 3. 
3 angle after, need to new before yaw anglecurrent_yaw, after toward before, distancecan long, such as5. 
"""
python_code = ernie_airsim.process(command)
print("python_code:", python_code)
