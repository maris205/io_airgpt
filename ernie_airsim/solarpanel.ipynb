# %%
import ernie_airsim
ernie_airsim = ernie_airsim.ErnieAirSim()

# %%
command = ""
python_code = ernie_airsim.process(command)
print("python_code:", python_code)

# %%
command = "90, toward solar panels. "
python_code = ernie_airsim.process(command)
print("python_code:", python_code)

# %%
command = """
in droneheading, in solar panels # edge. 

solar panels30 ( and X), long 50( and Y)

5 altitude. 

toward, toward #. 
note, Xshould is. 

after toward after 6, also is long toward, #. 

after toward, #, 

after toward after 6, below. 
"""
python_code = ernie_airsim.process(command)
print("python_code:", python_code)

# %%
command = ", above action3 times, note, each timesprocessbegin, all need todrone new position"
python_code = ernie_airsim.process(command)
print("python_code:", python_code)

# %%
command = " has, because is many timesloopexecute, each timesloopbegin, all need todrone new position. below "
python_code = ernie_airsim.process(command)
print("python_code:", python_code)
