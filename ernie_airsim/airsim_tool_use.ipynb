# %%
from airsim_wrapper import *
aw = AirSimWrapper() # Initialize AirSim, basic function calls

# %%
aw.takeoff()

# %%
car_position = aw.get_position("car")
aw.fly_to([car_position[0], car_position[1], car_position[2]+10])

# %%
aw.reset()

# %%
# #

# %%
aw = AirSimWrapper() # Initialize AirSim, basic function calls
aw.takeoff()

# %%
turbine_position = aw.get_position("turbine1") # get1 position
aw.fly_to(turbine_position) # drone1 position

# %%
turbine_position = aw.get_position("turbine2") # get2 position

# X and turbine12distance, 50 altitude
target_position = [turbine_position[0] + 12, turbine_position[1], turbine_position[2] + 50]

aw.fly_to(target_position) # dronetargetposition

# %%
current_position = aw.get_drone_position()

# before position above 30
target_position_up = [current_position[0], current_position[1], current_position[2] + 30]
aw.fly_to(target_position_up)
