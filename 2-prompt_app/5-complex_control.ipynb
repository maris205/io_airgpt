# %% [markdown]
# # 2.5 Complex Control - Wind Turbine Inspection

# %% [markdown]
# ## Task Execution Modes
# - Observation mode: the drone executes a single command at a time, using step-by-step instructions.
# - Process mode: the drone executes a complete workflow in sequence.
# - Agent mode: the drone observes and executes autonomously, making decisions on its own.

# %% [markdown]
# ## Task - Step-by-step Instructions
#
# Requirements:
# - The drone needs to be able to complete tasks based on the instructions below, one step at a time.
# - Each instruction is executed once. After execution, wait for the next instruction.
# - Instructions are sequential, forming a complete task.

# %%
# Build new prompt, write knowledge base to aisim_lession25.txt
kg_promot_file = "prompts/aisim_lession25.txt"

kg_prompt = """
Here are some functions you can use to command the drone.

aw.takeoff() - Take off the drone.
aw.land() - Land the drone.
aw.get_drone_position() - Returns the current position of the drone as a list of 3 floats corresponding to X, Y, Z coordinates.
aw.fly_to([x, y, z]) - Flies the drone to the specified position, given as a list of three arguments corresponding to X, Y, Z coordinates.
aw.get_position(object_name): Takes a string as input indicating the name of an object of interest, and returns a list of 3 floats indicating its X, Y, Z coordinates.

The following objects are in the scene, and you should refer to them using these exact names:

turbine1, turbine2, solarpanels, car, crowd, tower1, tower2, tower3.

For example, to get the position of turbine1, you should write:
aw.get_position("turbine1")

In terms of axis conventions, we use the NED (North-East-Down) coordinate system, where +X is North, +Y is East, and +Z is Down. This means the higher you fly, the more negative the Z value becomes. If the origin is on the ground, Z is zero at ground level and negative above ground. To fly up, subtract a value from the Z axis.

None of the objects except for the drone itself are movable. Remember that there are two turbines and three towers. When there are multiple objects of the same type, and if I do not explicitly specify which object I am referring to, you should always ask me for clarification. Never make assumptions.

Reply in the following example format:
```python
i=1  # output python code here
```
This code assigns a value.

You do not need to worry about importing aw; it is already declared in the environment.
"""

pt_file = open(kg_promot_file, "w", encoding="utf-8")
pt_file.write(kg_prompt)
pt_file.close()

# %%
import airsim_agent
my_agent = airsim_agent.AirSimAgent(knowledge_prompt="prompts/aisim_lession25.txt")

# %%
command = "take off"
python_code = my_agent.process(command, True) # Execute code
print("python_code: \n", python_code)

# %%
command = "Fly toward turbine1 along the X axis, and stop 10 meters before reaching it."
python_code = my_agent.process(command, True) # Execute code
print("python_code: \n", python_code)

# %%
command = "Continue flying toward turbine2. Keep X distance 12 meters from turbine2, fly toward turbine2 at altitude 50."
python_code = my_agent.process(command, True) # Execute code
print("python_code: \n", python_code)

# %%
command = "Now begin inspecting the wind turbine. First fly up 30 meters above the current position, then fly down. Note: flying up means Z becomes more negative."
python_code = my_agent.process(command, True) # Execute code
print("python_code:", python_code)

# %%
command = "Inspect the blade: fly 30 meters along the Y axis from the current position. Maintain 30 meters distance in the YZ plane, then return to the previous position."
python_code = my_agent.process(command, True) # Execute code
print("python_code:", python_code)

# %%
command = "Inspect the blade: fly 30 meters along the Y axis from the current position. Maintain 30 meters distance in the YZ plane, then return to the previous position."
python_code = my_agent.process(command, True) # Execute code
print("python_code:", python_code)

# %%
command = "Now perform the inspection action. Fly down, but after descending, do not return to the previous position."
python_code = my_agent.process(command, True) # Execute code
print("python_code:", python_code)

# %%
command = "Now fly to the front of the wind turbine (the other side). Move 20 meters along the X axis to pass between the turbines, then rotate the drone 180 degrees. You can use the set_yaw() function to rotate the drone."
python_code = my_agent.process(command, True) # Execute code
print("python_code:", python_code)

# %%
command = "Good! Now we need to inspect again. Same as before: fly up 30 meters, then fly down."
python_code = my_agent.process(command, True) # Execute code
print("python_code:", python_code)

# %%
command = "Next blade: fly up 30 meters above the current position, then fly down. Note: flying up means Z becomes more negative."
python_code = my_agent.process(command, True) # Execute code
print("python_code:", python_code)

# %%
command = "Inspect the blade: fly 30 meters along the Y axis from the current position. Maintain 30 meters distance in the YZ plane, then return to the previous position."
python_code = my_agent.process(command, True) # Execute code
print("python_code:", python_code)
